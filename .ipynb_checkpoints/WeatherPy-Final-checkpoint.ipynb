# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis- Three Observable Trends
# 1. As we get closer to the equator line, where the latitude is zero, the temperature rises, and it decreases as we move away from it, confirming our expectation. However, it is very interesting to compare cities with the same latitude in opposite hemispheres (Northern vs. Southern), since we oberve there is a slight concnetration of the distribution of cities in higher temperatures in the Northern Hemisphere. This might be due to the time of the year (end of summer, beginning of fall) in the Northern Hemisphere and the tilt of the terrestrial globe. Would be interesting to have access to historical data, comparing different seasons around the globe (winter, fall, summer and spring).
#
# 2. Observing the City Latitude vs. Humidity plot, we do not observe any trend between these two variables, since there is not a clear pattern. However, it is interesting to observe there are cities in both hemispheres at 100% humidity.
#
# 3. Observing the City Latitude vs. Cloudiness plot, there is not a observable trend that correlates latitude and cloudiness. However, it is very interesting to note there are bands of cities at 0, 20 and 80 cloudiness. It would be interesting to compare historical data from different times of the day distributed along time of the year (different seasons) to establish if there is correlation between time of the day, time of the year (season), latitude and cloudiness.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 626

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Building partial query URL with imperial system unit
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

city_ctr = 0
set_ctr = 1
cities_json = []

print(f"Beginning Data Retrieval")     
print(f"-----------------------------")
      
#Building cities_json using try_exception to handle cities without weather data
for city in cities:
    query_url = f"{url}appid={api_key}&units={units}&q="
    weather_json = requests.get(query_url + city).json()
    city_ctr += 1
      
    try:
        print(f"Processing Record " + str(city_ctr) + " of Set " + str(set_ctr) + " | " + city)
        city= weather_json["name"]
        cloudiness = weather_json["clouds"]["all"]
        country = weather_json["sys"]["country"]
        date = weather_json["dt"]
        humidity = weather_json["main"]["humidity"]
        lat = weather_json["coord"]["lat"]
        lng = weather_json["coord"]["lon"]
        max_temp = weather_json["main"]["temp_max"]
        wind_speed = weather_json["wind"]["speed"]
        
        cities_json.append({"City": city,"Cloudiness": cloudiness,"Country": country,
                            "Date": date,"Humidity": humidity,"Lat": lat,"Lng": lng,
                            "Max Temp": max_temp,"Wind Speed": wind_speed})        
                        
    except:
        print(f"City not found. Skipping...")
        
#OpenWeather API allows only 60 calls per minute (Free Account)       
    if city_ctr == 50:
            time.sleep(60) 
            city_ctr = 0
            set_ctr += 1
    
#printing the last rows to indicate that the processing log is over        
print(f"-----------------------------")
print(f"Data Retrieval Complete")
print(f"-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | road town
# Processing Record 3 of Set 1 | paita
# Processing Record 4 of Set 1 | saldanha
# Processing Record 5 of Set 1 | shangzhi
# Processing Record 6 of Set 1 | chuy
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | dingle
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | kahului
# Processing Record 11 of Set 1 | surgut
# Processing Record 12 of Set 1 | rungata
# City not found. Skipping...
# Processing Record 13 of Set 1 | formosa do rio preto
# Processing Record 14 of Set 1 | cape town
# Processing Record 15 of Set 1 | pangnirtung
# Processing Record 16 of Set 1 | butaritari
# Processing Record 17 of Set 1 | busselton
# Processing Record 18 of Set 1 | aksarka
# Processing Record 19 of Set 1 | paicol
# Processing Record 20 of Set 1 | tuktoyaktuk
# Processing Record 21 of Set 1 | jamestown
# Processing Record 22 of Set 1 | bonthe
# Processing Record 23 of Set 1 | pokanayevka
# City not found. Skipping...
# Processing Record 24 of Set 1 | alofi
# Processing Record 25 of Set 1 | mar del plata
# Processing Record 26 of Set 1 | ginir
# Processing Record 27 of Set 1 | nishihara
# Processing Record 28 of Set 1 | saint george
# Processing Record 29 of Set 1 | bethel
# Processing Record 30 of Set 1 | half moon bay
# Processing Record 31 of Set 1 | bereda
# Processing Record 32 of Set 1 | victoria
# Processing Record 33 of Set 1 | adrar
# Processing Record 34 of Set 1 | hermanus
# Processing Record 35 of Set 1 | tomatlan
# Processing Record 36 of Set 1 | podosinovets
# Processing Record 37 of Set 1 | saint anthony
# Processing Record 38 of Set 1 | hithadhoo
# Processing Record 39 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 40 of Set 1 | airai
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | vaini
# Processing Record 43 of Set 1 | barrow
# Processing Record 44 of Set 1 | prince rupert
# Processing Record 45 of Set 1 | pacific grove
# Processing Record 46 of Set 1 | kyrksaeterora
# Processing Record 47 of Set 1 | kamaishi
# Processing Record 48 of Set 1 | u thong
# Processing Record 49 of Set 1 | mayma
# Processing Record 50 of Set 1 | chokurdakh
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | buraydah
# Processing Record 3 of Set 2 | bluff
# Processing Record 4 of Set 2 | koyilandi
# City not found. Skipping...
# Processing Record 5 of Set 2 | provideniya
# Processing Record 6 of Set 2 | yellowknife
# Processing Record 7 of Set 2 | port elizabeth
# Processing Record 8 of Set 2 | sampit
# Processing Record 9 of Set 2 | pisco
# Processing Record 10 of Set 2 | clyde river
# Processing Record 11 of Set 2 | saint-augustin
# Processing Record 12 of Set 2 | morondava
# Processing Record 13 of Set 2 | cabedelo
# Processing Record 14 of Set 2 | imeni poliny osipenko
# Processing Record 15 of Set 2 | bilma
# Processing Record 16 of Set 2 | kapaa
# Processing Record 17 of Set 2 | souillac
# Processing Record 18 of Set 2 | san rafael
# Processing Record 19 of Set 2 | luderitz
# Processing Record 20 of Set 2 | port macquarie
# Processing Record 21 of Set 2 | bengkulu
# City not found. Skipping...
# Processing Record 22 of Set 2 | burgos
# Processing Record 23 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 24 of Set 2 | hof
# Processing Record 25 of Set 2 | hilo
# Processing Record 26 of Set 2 | atuona
# Processing Record 27 of Set 2 | caravelas
# Processing Record 28 of Set 2 | hamilton
# Processing Record 29 of Set 2 | gimli
# Processing Record 30 of Set 2 | kokopo
# Processing Record 31 of Set 2 | tasiilaq
# Processing Record 32 of Set 2 | porto-vecchio
# Processing Record 33 of Set 2 | broome
# Processing Record 34 of Set 2 | bagdarin
# Processing Record 35 of Set 2 | onda
# Processing Record 36 of Set 2 | kolyvan
# Processing Record 37 of Set 2 | port augusta
# Processing Record 38 of Set 2 | garden city
# Processing Record 39 of Set 2 | tavda
# Processing Record 40 of Set 2 | qaanaaq
# Processing Record 41 of Set 2 | mataura
# Processing Record 42 of Set 2 | alyangula
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | tottori
# Processing Record 45 of Set 2 | korla
# City not found. Skipping...
# Processing Record 46 of Set 2 | lompoc
# Processing Record 47 of Set 2 | bada
# Processing Record 48 of Set 2 | severo-kurilsk
# Processing Record 49 of Set 2 | noshiro
# Processing Record 50 of Set 2 | sorland
# Processing Record 1 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 3 | albany
# Processing Record 3 of Set 3 | glen burnie
# Processing Record 4 of Set 3 | san patricio
# Processing Record 5 of Set 3 | umzimvubu
# City not found. Skipping...
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | saskylakh
# Processing Record 8 of Set 3 | xam nua
# Processing Record 9 of Set 3 | puerto ayora
# Processing Record 10 of Set 3 | sao joao da barra
# Processing Record 11 of Set 3 | gat
# Processing Record 12 of Set 3 | constitucion
# Processing Record 13 of Set 3 | mehamn
# Processing Record 14 of Set 3 | nanortalik
# Processing Record 15 of Set 3 | kangaatsiaq
# Processing Record 16 of Set 3 | avarua
# Processing Record 17 of Set 3 | kamenka
# Processing Record 18 of Set 3 | bryan
# Processing Record 19 of Set 3 | lata
# Processing Record 20 of Set 3 | asau
# City not found. Skipping...
# Processing Record 21 of Set 3 | flin flon
# Processing Record 22 of Set 3 | twentynine palms
# Processing Record 23 of Set 3 | bathsheba
# Processing Record 24 of Set 3 | hellin
# Processing Record 25 of Set 3 | kodiak
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | karratha
# Processing Record 28 of Set 3 | batouri
# Processing Record 29 of Set 3 | faanui
# Processing Record 30 of Set 3 | imbituba
# Processing Record 31 of Set 3 | cockburn town
# Processing Record 32 of Set 3 | dikson
# Processing Record 33 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 34 of Set 3 | thompson
# Processing Record 35 of Set 3 | east london
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | zlobin
# Processing Record 38 of Set 3 | upernavik
# Processing Record 39 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 40 of Set 3 | flinders
# Processing Record 41 of Set 3 | cabo san lucas
# Processing Record 42 of Set 3 | dillingen
# Processing Record 43 of Set 3 | touros
# Processing Record 44 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 3 | poum
# Processing Record 46 of Set 3 | cururupu
# Processing Record 47 of Set 3 | norman wells
# Processing Record 48 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 49 of Set 3 | georgetown
# Processing Record 50 of Set 3 | natchez
# Processing Record 1 of Set 4 | belaya gora
# Processing Record 2 of Set 4 | sierra vista
# Processing Record 3 of Set 4 | gabu
# Processing Record 4 of Set 4 | palana
# Processing Record 5 of Set 4 | petrolandia
# City not found. Skipping...
# Processing Record 6 of Set 4 | jawhar
# Processing Record 7 of Set 4 | honiara
# Processing Record 8 of Set 4 | la ronge
# Processing Record 9 of Set 4 | cidreira
# Processing Record 10 of Set 4 | jurm
# Processing Record 11 of Set 4 | mizan teferi
# Processing Record 12 of Set 4 | unity
# Processing Record 13 of Set 4 | denpasar
# Processing Record 14 of Set 4 | long beach
# Processing Record 15 of Set 4 | sao filipe
# Processing Record 16 of Set 4 | mangai
# Processing Record 17 of Set 4 | comodoro rivadavia
# Processing Record 18 of Set 4 | malakal
# City not found. Skipping...
# Processing Record 19 of Set 4 | evensk
# Processing Record 20 of Set 4 | montepuez
# Processing Record 21 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 22 of Set 4 | ixtapa
# Processing Record 23 of Set 4 | ribeira grande
# Processing Record 24 of Set 4 | port hedland
# Processing Record 25 of Set 4 | pevek
# Processing Record 26 of Set 4 | saint-philippe
# Processing Record 27 of Set 4 | longyearbyen
# Processing Record 28 of Set 4 | north bend
# Processing Record 29 of Set 4 | arraial do cabo
# Processing Record 30 of Set 4 | kabare
# Processing Record 31 of Set 4 | antalaha
# Processing Record 32 of Set 4 | sarwar
# Processing Record 33 of Set 4 | pierre
# Processing Record 34 of Set 4 | port hawkesbury
# Processing Record 35 of Set 4 | carnarvon
# Processing Record 36 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 37 of Set 4 | maltahohe
# Processing Record 38 of Set 4 | east wenatchee bench
# Processing Record 39 of Set 4 | channel-port aux basques
# Processing Record 40 of Set 4 | sibolga
# Processing Record 41 of Set 4 | morant bay
# Processing Record 42 of Set 4 | grindavik
# Processing Record 43 of Set 4 | tiksi
# Processing Record 44 of Set 4 | barbar
# City not found. Skipping...
# Processing Record 45 of Set 4 | bambous virieux
# Processing Record 46 of Set 4 | kieta
# Processing Record 47 of Set 4 | santa rita
# Processing Record 48 of Set 4 | avera
# Processing Record 49 of Set 4 | tabat
# Processing Record 50 of Set 4 | walvis bay
# Processing Record 1 of Set 5 | camana
# City not found. Skipping...
# Processing Record 2 of Set 5 | port blair
# Processing Record 3 of Set 5 | pangkalanbuun
# Processing Record 4 of Set 5 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 5 of Set 5 | husavik
# Processing Record 6 of Set 5 | moerai
# Processing Record 7 of Set 5 | esperance
# Processing Record 8 of Set 5 | wynyard
# Processing Record 9 of Set 5 | manta
# Processing Record 10 of Set 5 | attawapiskat
# City not found. Skipping...
# Processing Record 11 of Set 5 | lebu
# Processing Record 12 of Set 5 | cayenne
# Processing Record 13 of Set 5 | santa rosa
# Processing Record 14 of Set 5 | basoko
# Processing Record 15 of Set 5 | chulym
# Processing Record 16 of Set 5 | kawalu
# Processing Record 17 of Set 5 | samalaeulu
# City not found. Skipping...
# Processing Record 18 of Set 5 | port lincoln
# Processing Record 19 of Set 5 | columbus
# Processing Record 20 of Set 5 | zacatecas
# Processing Record 21 of Set 5 | cherskiy
# Processing Record 22 of Set 5 | jumla
# Processing Record 23 of Set 5 | kavieng
# Processing Record 24 of Set 5 | castro
# Processing Record 25 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 26 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 27 of Set 5 | kramat
# Processing Record 28 of Set 5 | karkaralinsk
# City not found. Skipping...
# Processing Record 29 of Set 5 | bud
# Processing Record 30 of Set 5 | novyy urengoy
# Processing Record 31 of Set 5 | yulara
# Processing Record 32 of Set 5 | ulladulla
# Processing Record 33 of Set 5 | dzhusaly
# City not found. Skipping...
# Processing Record 34 of Set 5 | maniitsoq
# Processing Record 35 of Set 5 | borujan
# City not found. Skipping...
# Processing Record 36 of Set 5 | gouyave
# Processing Record 37 of Set 5 | kashi
# City not found. Skipping...
# Processing Record 38 of Set 5 | pitimbu
# Processing Record 39 of Set 5 | vestmannaeyjar
# Processing Record 40 of Set 5 | college
# Processing Record 41 of Set 5 | miyazu
# Processing Record 42 of Set 5 | yuci
# Processing Record 43 of Set 5 | okhotsk
# Processing Record 44 of Set 5 | escanaba
# Processing Record 45 of Set 5 | aklavik
# Processing Record 46 of Set 5 | linxia
# Processing Record 47 of Set 5 | mareeba
# Processing Record 48 of Set 5 | porosozero
# Processing Record 49 of Set 5 | thung song
# Processing Record 50 of Set 5 | pimentel
# Processing Record 1 of Set 6 | dalvik
# Processing Record 2 of Set 6 | narsaq
# Processing Record 3 of Set 6 | chifeng
# Processing Record 4 of Set 6 | kruisfontein
# Processing Record 5 of Set 6 | reconquista
# Processing Record 6 of Set 6 | raymondville
# Processing Record 7 of Set 6 | kaitangata
# Processing Record 8 of Set 6 | thaba-tseka
# Processing Record 9 of Set 6 | huilong
# Processing Record 10 of Set 6 | kungalv
# Processing Record 11 of Set 6 | tura
# Processing Record 12 of Set 6 | dunedin
# Processing Record 13 of Set 6 | ewa beach
# Processing Record 14 of Set 6 | turukhansk
# Processing Record 15 of Set 6 | fort stewart
# Processing Record 16 of Set 6 | khatanga
# Processing Record 17 of Set 6 | cheuskiny
# City not found. Skipping...
# Processing Record 18 of Set 6 | juba
# Processing Record 19 of Set 6 | mahebourg
# Processing Record 20 of Set 6 | lakatoro
# Processing Record 21 of Set 6 | launceston
# Processing Record 22 of Set 6 | talnakh
# Processing Record 23 of Set 6 | izazi
# Processing Record 24 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 25 of Set 6 | poltavka
# Processing Record 26 of Set 6 | edd
# Processing Record 27 of Set 6 | malpe
# Processing Record 28 of Set 6 | smithers
# Processing Record 29 of Set 6 | rio grande
# Processing Record 30 of Set 6 | faya
# Processing Record 31 of Set 6 | svetlogorsk
# Processing Record 32 of Set 6 | djibo
# Processing Record 33 of Set 6 | nemuro
# Processing Record 34 of Set 6 | shingu
# Processing Record 35 of Set 6 | harer
# Processing Record 36 of Set 6 | havoysund
# Processing Record 37 of Set 6 | qurayyat
# City not found. Skipping...
# Processing Record 38 of Set 6 | banjarmasin
# Processing Record 39 of Set 6 | high rock
# Processing Record 40 of Set 6 | la palma
# Processing Record 41 of Set 6 | kuhdasht
# Processing Record 42 of Set 6 | lodja
# Processing Record 43 of Set 6 | honningsvag
# Processing Record 44 of Set 6 | casian
# Processing Record 45 of Set 6 | narsipatnam
# Processing Record 46 of Set 6 | arman
# Processing Record 47 of Set 6 | izacic
# Processing Record 48 of Set 6 | merauke
# Processing Record 49 of Set 6 | ornskoldsvik
# Processing Record 50 of Set 6 | carinhanha
# Processing Record 1 of Set 7 | shache
# Processing Record 2 of Set 7 | mombetsu
# Processing Record 3 of Set 7 | labuhan
# Processing Record 4 of Set 7 | narrabri
# Processing Record 5 of Set 7 | llanelli
# Processing Record 6 of Set 7 | srandakan
# Processing Record 7 of Set 7 | raudeberg
# Processing Record 8 of Set 7 | liwale
# Processing Record 9 of Set 7 | kushima
# Processing Record 10 of Set 7 | kavaratti
# Processing Record 11 of Set 7 | arklow
# Processing Record 12 of Set 7 | heze
# Processing Record 13 of Set 7 | namibe
# Processing Record 14 of Set 7 | yenagoa
# Processing Record 15 of Set 7 | samusu
# City not found. Skipping...
# Processing Record 16 of Set 7 | nara
# Processing Record 17 of Set 7 | apac
# Processing Record 18 of Set 7 | moussoro
# Processing Record 19 of Set 7 | sestri levante
# Processing Record 20 of Set 7 | pecos
# Processing Record 21 of Set 7 | novo aripuana
# Processing Record 22 of Set 7 | brunswick
# Processing Record 23 of Set 7 | adeje
# Processing Record 24 of Set 7 | tadine
# Processing Record 25 of Set 7 | lisa
# Processing Record 26 of Set 7 | saint-georges
# Processing Record 27 of Set 7 | batemans bay
# Processing Record 28 of Set 7 | geraldton
# Processing Record 29 of Set 7 | iqaluit
# Processing Record 30 of Set 7 | harigue
# City not found. Skipping...
# Processing Record 31 of Set 7 | mana
# Processing Record 32 of Set 7 | ostrovnoy
# Processing Record 33 of Set 7 | horsham
# Processing Record 34 of Set 7 | zhuanghe
# Processing Record 35 of Set 7 | leh
# Processing Record 36 of Set 7 | ponta do sol
# Processing Record 37 of Set 7 | vila franca do campo
# Processing Record 38 of Set 7 | puerto maldonado
# Processing Record 39 of Set 7 | hasaki
# Processing Record 40 of Set 7 | tamandare
# Processing Record 41 of Set 7 | batagay-alyta
# Processing Record 42 of Set 7 | kyzyl-suu
# Processing Record 43 of Set 7 | sobolevo
# Processing Record 44 of Set 7 | gizo
# Processing Record 45 of Set 7 | talcahuano
# Processing Record 46 of Set 7 | catamarca
# City not found. Skipping...
# Processing Record 47 of Set 7 | pangody
# Processing Record 48 of Set 7 | kloulklubed
# Processing Record 49 of Set 7 | belyy yar
# Processing Record 50 of Set 7 | ucluelet
# Processing Record 1 of Set 8 | menongue
# Processing Record 2 of Set 8 | deputatskiy
# Processing Record 3 of Set 8 | harper
# Processing Record 4 of Set 8 | leningradskiy
# Processing Record 5 of Set 8 | darnah
# Processing Record 6 of Set 8 | puttur
# Processing Record 7 of Set 8 | moron
# Processing Record 8 of Set 8 | bima
# Processing Record 9 of Set 8 | hambantota
# Processing Record 10 of Set 8 | vestmanna
# Processing Record 11 of Set 8 | lavrentiya
# Processing Record 12 of Set 8 | seoul
# Processing Record 13 of Set 8 | pampas
# Processing Record 14 of Set 8 | nantucket
# Processing Record 15 of Set 8 | lerik
# Processing Record 16 of Set 8 | chapleau
# Processing Record 17 of Set 8 | nome
# Processing Record 18 of Set 8 | codrington
# Processing Record 19 of Set 8 | rundu
# Processing Record 20 of Set 8 | tobermory
# Processing Record 21 of Set 8 | shigony
# Processing Record 22 of Set 8 | zeya
# Processing Record 23 of Set 8 | tuatapere
# Processing Record 24 of Set 8 | tabiauea
# City not found. Skipping...
# Processing Record 25 of Set 8 | yining
# Processing Record 26 of Set 8 | kalmunai
# Processing Record 27 of Set 8 | aswan
# Processing Record 28 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 29 of Set 8 | qasigiannguit
# Processing Record 30 of Set 8 | paamiut
# Processing Record 31 of Set 8 | logansport
# Processing Record 32 of Set 8 | yumen
# Processing Record 33 of Set 8 | burica
# City not found. Skipping...
# Processing Record 34 of Set 8 | vallenar
# Processing Record 35 of Set 8 | suez
# Processing Record 36 of Set 8 | mattru
# Processing Record 37 of Set 8 | greeneville
# Processing Record 38 of Set 8 | tawkar
# City not found. Skipping...
# Processing Record 39 of Set 8 | khatra
# Processing Record 40 of Set 8 | key west
# Processing Record 41 of Set 8 | bonfim
# Processing Record 42 of Set 8 | san quintin
# Processing Record 43 of Set 8 | west bay
# Processing Record 44 of Set 8 | najran
# Processing Record 45 of Set 8 | saint-paul
# Processing Record 46 of Set 8 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 8 | kamiiso
# Processing Record 48 of Set 8 | broken hill
# Processing Record 49 of Set 8 | maracas
# Processing Record 50 of Set 8 | salym
# Processing Record 1 of Set 9 | tabulbah
# City not found. Skipping...
# Processing Record 2 of Set 9 | sechura
# Processing Record 3 of Set 9 | abancay
# Processing Record 4 of Set 9 | ondorhaan
# City not found. Skipping...
# Processing Record 5 of Set 9 | ambilobe
# Processing Record 6 of Set 9 | luanda
# Processing Record 7 of Set 9 | vitoria do mearim
# Processing Record 8 of Set 9 | katsuura
# Processing Record 9 of Set 9 | ituni
# City not found. Skipping...
# Processing Record 10 of Set 9 | bulawayo
# Processing Record 11 of Set 9 | sakaiminato
# Processing Record 12 of Set 9 | samarai
# Processing Record 13 of Set 9 | peto
# Processing Record 14 of Set 9 | plattsburgh
# Processing Record 15 of Set 9 | xining
# Processing Record 16 of Set 9 | puerto quijarro
# Processing Record 17 of Set 9 | klyuchi
# Processing Record 18 of Set 9 | puerto escondido
# Processing Record 19 of Set 9 | almaznyy
# Processing Record 20 of Set 9 | rocha
# Processing Record 21 of Set 9 | abu dhabi
# Processing Record 22 of Set 9 | karaul
# City not found. Skipping...
# Processing Record 23 of Set 9 | ponta delgada
# Processing Record 24 of Set 9 | weligama
# Processing Record 25 of Set 9 | rancho palos verdes
# Processing Record 26 of Set 9 | tumannyy
# City not found. Skipping...
# Processing Record 27 of Set 9 | muros
# Processing Record 28 of Set 9 | coquimbo
# Processing Record 29 of Set 9 | sabrum
# Processing Record 30 of Set 9 | berlevag
# Processing Record 31 of Set 9 | yar-sale
# Processing Record 32 of Set 9 | ilulissat
# Processing Record 33 of Set 9 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 9 | ozgon
# City not found. Skipping...
# Processing Record 35 of Set 9 | yaan
# Processing Record 36 of Set 9 | warqla
# City not found. Skipping...
# Processing Record 37 of Set 9 | tonantins
# Processing Record 38 of Set 9 | port hardy
# Processing Record 39 of Set 9 | coahuayana
# Processing Record 40 of Set 9 | newport
# Processing Record 41 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 42 of Set 9 | bekwai
# Processing Record 43 of Set 9 | olafsvik
# City not found. Skipping...
# Processing Record 44 of Set 9 | praia da vitoria
# Processing Record 45 of Set 9 | angoche
# Processing Record 46 of Set 9 | tagusao
# Processing Record 47 of Set 9 | qostanay
# Processing Record 48 of Set 9 | ubeda
# Processing Record 49 of Set 9 | smolensk
# Processing Record 50 of Set 9 | ekhabi
# Processing Record 1 of Set 10 | narok
# Processing Record 2 of Set 10 | alice springs
# Processing Record 3 of Set 10 | bundaberg
# Processing Record 4 of Set 10 | padang
# Processing Record 5 of Set 10 | contamana
# Processing Record 6 of Set 10 | kadykchan
# City not found. Skipping...
# Processing Record 7 of Set 10 | verkh-chebula
# Processing Record 8 of Set 10 | mubende
# Processing Record 9 of Set 10 | tir pol
# City not found. Skipping...
# Processing Record 10 of Set 10 | brae
# Processing Record 11 of Set 10 | margate
# Processing Record 12 of Set 10 | mahwa
# Processing Record 13 of Set 10 | lengshuijiang
# Processing Record 14 of Set 10 | gibara
# Processing Record 15 of Set 10 | priargunsk
# Processing Record 16 of Set 10 | langenburg
# Processing Record 17 of Set 10 | milingimbi
# City not found. Skipping...
# Processing Record 18 of Set 10 | visnes
# Processing Record 19 of Set 10 | cartagena del chaira
# Processing Record 20 of Set 10 | luganville
# Processing Record 21 of Set 10 | mundo nuevo
# Processing Record 22 of Set 10 | vostok
# Processing Record 23 of Set 10 | guerrero negro
# Processing Record 24 of Set 10 | leopold
# Processing Record 25 of Set 10 | beyneu
# Processing Record 26 of Set 10 | ulaangom
# Processing Record 27 of Set 10 | cortes
# Processing Record 28 of Set 10 | guajara-mirim
# City not found. Skipping...
# Processing Record 29 of Set 10 | kaeo
# Processing Record 30 of Set 10 | lira
# Processing Record 31 of Set 10 | tateyama
# Processing Record 32 of Set 10 | bandarbeyla
# Processing Record 33 of Set 10 | dandong
# Processing Record 34 of Set 10 | baykit
# Processing Record 35 of Set 10 | rio de janeiro
# Processing Record 36 of Set 10 | kirsanov
# Processing Record 37 of Set 10 | urengoy
# Processing Record 38 of Set 10 | dwarka
# Processing Record 39 of Set 10 | te anau
# Processing Record 40 of Set 10 | kargala
# Processing Record 41 of Set 10 | dire dawa
# Processing Record 42 of Set 10 | north las vegas
# Processing Record 43 of Set 10 | viedma
# Processing Record 44 of Set 10 | mount isa
# Processing Record 45 of Set 10 | tautira
# Processing Record 46 of Set 10 | arawa
# Processing Record 47 of Set 10 | yoichi
# Processing Record 48 of Set 10 | guozhen
# Processing Record 49 of Set 10 | narayanganj
# Processing Record 50 of Set 10 | buala
# Processing Record 1 of Set 11 | mossendjo
# Processing Record 2 of Set 11 | aranos
# Processing Record 3 of Set 11 | litovko
# Processing Record 4 of Set 11 | quelimane
# Processing Record 5 of Set 11 | port moresby
# Processing Record 6 of Set 11 | sonoita
# Processing Record 7 of Set 11 | laguna
# Processing Record 8 of Set 11 | zhuhai
# Processing Record 9 of Set 11 | voznesenye
# Processing Record 10 of Set 11 | muyezerskiy
# Processing Record 11 of Set 11 | hoyanger
# Processing Record 12 of Set 11 | miandrivazo
# Processing Record 13 of Set 11 | northam
# Processing Record 14 of Set 11 | sur
# Processing Record 15 of Set 11 | coihaique
# Processing Record 16 of Set 11 | rawson
# Processing Record 17 of Set 11 | sulangan
# Processing Record 18 of Set 11 | turayf
# Processing Record 19 of Set 11 | oneida
# Processing Record 20 of Set 11 | bonnyville
# Processing Record 21 of Set 11 | altay
# Processing Record 22 of Set 11 | ola
# Processing Record 23 of Set 11 | jaspur
# Processing Record 24 of Set 11 | warrington
# Processing Record 25 of Set 11 | pochutla
# Processing Record 26 of Set 11 | wajima
# Processing Record 27 of Set 11 | iberia
# Processing Record 28 of Set 11 | vilhena
# Processing Record 29 of Set 11 | vila do maio
# Processing Record 30 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 31 of Set 11 | portland
# Processing Record 32 of Set 11 | kathu
# Processing Record 33 of Set 11 | san jose
# Processing Record 34 of Set 11 | mount gambier
# Processing Record 35 of Set 11 | hobyo
# Processing Record 36 of Set 11 | sitka
# Processing Record 37 of Set 11 | omsukchan
# Processing Record 38 of Set 11 | jahrom
# City not found. Skipping...
# Processing Record 39 of Set 11 | sumbawa
# City not found. Skipping...
# Processing Record 40 of Set 11 | kidal
# Processing Record 41 of Set 11 | hammerfest
# Processing Record 42 of Set 11 | la sarre
# Processing Record 43 of Set 11 | manono
# Processing Record 44 of Set 11 | lalsot
# Processing Record 45 of Set 11 | pankovka
# Processing Record 46 of Set 11 | worcester
# Processing Record 47 of Set 11 | quesnel
# Processing Record 48 of Set 11 | george
# Processing Record 49 of Set 11 | sayyan
# Processing Record 50 of Set 11 | savalou
# Processing Record 1 of Set 12 | ust-maya
# Processing Record 2 of Set 12 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 3 of Set 12 | phonhong
# Processing Record 4 of Set 12 | golkoy
# Processing Record 5 of Set 12 | azovskaya
# Processing Record 6 of Set 12 | antofagasta
# Processing Record 7 of Set 12 | fortuna
# Processing Record 8 of Set 12 | kailua
# Processing Record 9 of Set 12 | salalah
# Processing Record 10 of Set 12 | schwedt
# City not found. Skipping...
# Processing Record 11 of Set 12 | gamba
# Processing Record 12 of Set 12 | mnogovershinnyy
# Processing Record 13 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 14 of Set 12 | adzope
# Processing Record 15 of Set 12 | strezhevoy
# Processing Record 16 of Set 12 | cap-aux-meules
# Processing Record 17 of Set 12 | zhezkazgan
# Processing Record 18 of Set 12 | kazalinsk
# City not found. Skipping...
# Processing Record 19 of Set 12 | horta
# Processing Record 20 of Set 12 | ranfurly
# Processing Record 21 of Set 12 | aleksandrov gay
# Processing Record 22 of Set 12 | hirara
# Processing Record 23 of Set 12 | raga
# City not found. Skipping...
# Processing Record 24 of Set 12 | baker city
# Processing Record 25 of Set 12 | mari-turek
# Processing Record 26 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 27 of Set 12 | lapua
# Processing Record 28 of Set 12 | ahipara
# Processing Record 29 of Set 12 | beloha
# Processing Record 30 of Set 12 | taoudenni
# Processing Record 31 of Set 12 | altagracia de orituco
# Processing Record 32 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 33 of Set 12 | gucheng
# Processing Record 34 of Set 12 | zhigansk
# Processing Record 35 of Set 12 | panaba
# Processing Record 36 of Set 12 | dekoa
# City not found. Skipping...
# Processing Record 37 of Set 12 | vao
# Processing Record 38 of Set 12 | sao pedro do sul
# Processing Record 39 of Set 12 | makat
# Processing Record 40 of Set 12 | krasnoselkup
# City not found. Skipping...
# Processing Record 41 of Set 12 | ahuimanu
# Processing Record 42 of Set 12 | rorvik
# Processing Record 43 of Set 12 | zhangye
# Processing Record 44 of Set 12 | camacha
# Processing Record 45 of Set 12 | saint-pierre
# Processing Record 46 of Set 12 | saurimo
# Processing Record 47 of Set 12 | dryden
# Processing Record 48 of Set 12 | manzhouli
# Processing Record 49 of Set 12 | ancud
# Processing Record 50 of Set 12 | garowe
# Processing Record 1 of Set 13 | los llanos de aridane
# Processing Record 2 of Set 13 | newtownards
# Processing Record 3 of Set 13 | chissamba
# City not found. Skipping...
# Processing Record 4 of Set 13 | maamba
# Processing Record 5 of Set 13 | stephenville
# Processing Record 6 of Set 13 | nouadhibou
# Processing Record 7 of Set 13 | kutum
# Processing Record 8 of Set 13 | cabatuan
# Processing Record 9 of Set 13 | kathmandu
# Processing Record 10 of Set 13 | richards bay
# Processing Record 11 of Set 13 | ovalle
# Processing Record 12 of Set 13 | lasa
# Processing Record 13 of Set 13 | mokshan
# Processing Record 14 of Set 13 | bara
# Processing Record 15 of Set 13 | beringovskiy
# Processing Record 16 of Set 13 | lagoa
# Processing Record 17 of Set 13 | vila velha
# Processing Record 18 of Set 13 | herat
# Processing Record 19 of Set 13 | lorengau
# Processing Record 20 of Set 13 | aqtobe
# Processing Record 21 of Set 13 | chapais
# Processing Record 22 of Set 13 | fort nelson
# Processing Record 23 of Set 13 | peniche
# Processing Record 24 of Set 13 | hilter
# Processing Record 25 of Set 13 | verkhnyaya inta
# Processing Record 26 of Set 13 | anadyr
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#Building pd dataframe from json file
df_cities = pd.DataFrame(cities_json)

#df to csv file with header but without index
df_cities.to_csv("city_data.csv", index=False, header=True)

# %%
#df count 
df_cities.count()
# Out:
# City          560
# Cloudiness    560
# Country       560
# Date          560
# Humidity      560
# Lat           560
# Lng           560
# Max Temp      560
# Wind Speed    560
# dtype: int64

# %%
#Displaying df first rows 
df_cities.head()
# Out:
#         City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0    Ushuaia          40      AR  1537804800        74 -54.81  -68.31
# 1  Road Town          40      VG  1537804800        66  18.42  -64.62
# 2      Paita           0      PE  1537804800       290  -5.09  -81.11
# 3   Saldanha           0      PT  1537807857        39  41.42   -6.55
# 4   Shangzhi          12      CN  1537807857        99  45.21  127.96
#
#    Max Temp  Wind Speed
# 0     41.00       21.92
# 1     89.60       11.41
# 2     62.60       10.29
# 3     79.23        4.97
# 4     44.58        5.08

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(df_cities["Lat"],df_cities["Max Temp"], marker="o", facecolors="#2474AC", edgecolors="black", alpha=0.8)
plt.title("City Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.xlim(-65,85)
plt.ylim(0,115)
plt.grid()
plt.savefig("temp.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df_cities["Lat"],df_cities["Humidity"], marker="o", facecolors="#2474AC", edgecolors="black", alpha=0.8)
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.xlim(-65,85)
plt.ylim(0,110)

plt.grid()
plt.savefig("humidity.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df_cities["Lat"],df_cities["Cloudiness"], marker="o", facecolors="#2474AC", edgecolors="black", alpha=0.8)
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.xlim(-65,85)
plt.ylim(-10,105)

plt.grid()
plt.savefig("cloudiness.png")
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df_cities["Lat"],df_cities["Wind Speed"], marker="o", facecolors="#2474AC", edgecolors="black", alpha=0.8)
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.xlim(-65,85)
plt.ylim(-2,40)
plt.grid()
plt.savefig("wind.png")
plt.show()
