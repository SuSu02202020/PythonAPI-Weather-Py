# %% [markdown]
# # WeatherPy
# ----
#
# ### Analysis
# * As expected, the weather becomes significantly warmer as one approaches the equator (0 Deg. Latitude). More interestingly, however, is the fact that the southern hemisphere tends to be warmer this time of year than the northern hemisphere. This may be due to the tilt of the earth.
# * There is no strong relationship between latitude and cloudiness. However, it is interesting to see that a strong band of cities sits at 0, 80, and 100% cloudiness.
# * There is no strong relationship between latitude and wind speed. However, in northern hemispheres there is a flurry of cities with over 20 mph of wind.
#
# ---
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 624

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Build partial query URL
url = "http://api.openweathermap.org/data/2.5/weather?"
units = "imperial"

# Build query URL

print(f"Beginning Data Retrieval")     
print(f"-----------------------------")
count = 0

cities_json = []

for city in cities:
   # query_url = url + "appid=" + api_key + "&q=" + city
    query_url = f"{url}appid={api_key}&units={units}&q="
    weather_json = requests.get(query_url + city).json()
    count += 1
    try:
        print(f"Processing Record " + str(count) + " of Set 1 | " + city)
        city= weather_json["name"]
        cloudiness = weather_json["clouds"]["all"]
        country = weather_json["sys"]["country"]
        date = weather_json["dt"]
        humidity = weather_json["main"]["humidity"]
        lat = weather_json["coord"]["lat"]
        lng = weather_json["coord"]["lon"]
        max_temp = weather_json["main"]["temp_max"]
        wind_speed = weather_json["wind"]["speed"]
        
        cities_json.append({"City": city,
                            "Cloudiness": cloudiness,
                            "Country": country,
                            "Date": date,
                            "Humidity": humidity,
                            "Lat": lat,
                            "Lng": lng,
                            "Max Temp": max_temp,
                            "Wind Speed": wind_speed,
                            })
         
        
    except:
        print(f"City not found. Skipping...")
        
print(f"-----------------------------")
print(f"Data Retrieval Complete")
print(f"-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | stornoway
# City not found. Skipping...
# Processing Record 2 of Set 1 | vitim
# Processing Record 3 of Set 1 | bluff
# Processing Record 4 of Set 1 | springbok
# Processing Record 5 of Set 1 | broken hill
# Processing Record 6 of Set 1 | lazarev
# Processing Record 7 of Set 1 | fenoarivo
# Processing Record 8 of Set 1 | esperance
# Processing Record 9 of Set 1 | upernavik
# Processing Record 10 of Set 1 | hobart
# Processing Record 11 of Set 1 | qaanaaq
# Processing Record 12 of Set 1 | ostrovnoy
# Processing Record 13 of Set 1 | albany
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | cape town
# Processing Record 16 of Set 1 | pimentel
# Processing Record 17 of Set 1 | port macquarie
# Processing Record 18 of Set 1 | punta arenas
# Processing Record 19 of Set 1 | lompoc
# Processing Record 20 of Set 1 | el alto
# Processing Record 21 of Set 1 | moa
# Processing Record 22 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 23 of Set 1 | mataura
# Processing Record 24 of Set 1 | otane
# Processing Record 25 of Set 1 | atuona
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# Processing Record 27 of Set 1 | nantucket
# Processing Record 28 of Set 1 | codrington
# Processing Record 29 of Set 1 | nurota
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | cherskiy
# Processing Record 32 of Set 1 | havelock
# Processing Record 33 of Set 1 | kruisfontein
# Processing Record 34 of Set 1 | mandalgovi
# Processing Record 35 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 36 of Set 1 | ushuaia
# Processing Record 37 of Set 1 | fortuna
# Processing Record 38 of Set 1 | sao filipe
# Processing Record 39 of Set 1 | sao joao da barra
# Processing Record 40 of Set 1 | berlevag
# Processing Record 41 of Set 1 | taoudenni
# Processing Record 42 of Set 1 | new norfolk
# Processing Record 43 of Set 1 | chimore
# Processing Record 44 of Set 1 | carnarvon
# Processing Record 45 of Set 1 | port alfred
# Processing Record 46 of Set 1 | tuktoyaktuk
# Processing Record 47 of Set 1 | khatanga
# Processing Record 48 of Set 1 | amderma
# City not found. Skipping...
# Processing Record 49 of Set 1 | juneau
# Processing Record 50 of Set 1 | busselton
# Processing Record 51 of Set 1 | dubuque
# Processing Record 52 of Set 1 | lhokseumawe
# Processing Record 53 of Set 1 | san cristobal
# Processing Record 54 of Set 1 | georgetown
# Processing Record 55 of Set 1 | absam
# Processing Record 56 of Set 1 | high prairie
# Processing Record 57 of Set 1 | bambous virieux
# Processing Record 58 of Set 1 | ahipara
# Processing Record 59 of Set 1 | tunduru
# City not found. Skipping...
# Processing Record 60 of Set 1 | vardo
# Processing Record 61 of Set 1 | kodiak
# Processing Record 62 of Set 1 | rio grande
# Processing Record 63 of Set 1 | ngawen
# Processing Record 64 of Set 1 | mahebourg
# Processing Record 65 of Set 1 | saint-philippe
# Processing Record 66 of Set 1 | aksu
# Processing Record 67 of Set 1 | kaitangata
# Processing Record 68 of Set 1 | thompson
# Processing Record 69 of Set 1 | beringovskiy
# Processing Record 70 of Set 1 | hermanus
# Processing Record 71 of Set 1 | valparaiso
# Processing Record 72 of Set 1 | dikson
# Processing Record 73 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 74 of Set 1 | abu samrah
# Processing Record 75 of Set 1 | bengkulu
# City not found. Skipping...
# Processing Record 76 of Set 1 | ushtobe
# Processing Record 77 of Set 1 | revuca
# Processing Record 78 of Set 1 | babu
# Processing Record 79 of Set 1 | labutta
# City not found. Skipping...
# Processing Record 80 of Set 1 | kapaa
# Processing Record 81 of Set 1 | nikolskoye
# Processing Record 82 of Set 1 | puerto ayacucho
# Processing Record 83 of Set 1 | shadegan
# Processing Record 84 of Set 1 | yinchuan
# Processing Record 85 of Set 1 | mount isa
# Processing Record 86 of Set 1 | bredasdorp
# Processing Record 87 of Set 1 | leh
# Processing Record 88 of Set 1 | airai
# Processing Record 89 of Set 1 | bella vista
# Processing Record 90 of Set 1 | arraial do cabo
# Processing Record 91 of Set 1 | raudeberg
# Processing Record 92 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 93 of Set 1 | salalah
# Processing Record 94 of Set 1 | sur
# Processing Record 95 of Set 1 | ponta do sol
# Processing Record 96 of Set 1 | cowra
# Processing Record 97 of Set 1 | hilo
# Processing Record 98 of Set 1 | saskylakh
# Processing Record 99 of Set 1 | astana
# Processing Record 100 of Set 1 | severo-kurilsk
# Processing Record 101 of Set 1 | skalistyy
# City not found. Skipping...
# Processing Record 102 of Set 1 | caconda
# Processing Record 103 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 104 of Set 1 | chipinge
# Processing Record 105 of Set 1 | cap malheureux
# Processing Record 106 of Set 1 | narsaq
# Processing Record 107 of Set 1 | teeli
# Processing Record 108 of Set 1 | daru
# Processing Record 109 of Set 1 | chimoio
# Processing Record 110 of Set 1 | butaritari
# Processing Record 111 of Set 1 | srednekolymsk
# Processing Record 112 of Set 1 | kathmandu
# Processing Record 113 of Set 1 | bogorodskoye
# Processing Record 114 of Set 1 | sorland
# Processing Record 115 of Set 1 | rawson
# Processing Record 116 of Set 1 | isangel
# Processing Record 117 of Set 1 | talnakh
# Processing Record 118 of Set 1 | salvador
# Processing Record 119 of Set 1 | husavik
# Processing Record 120 of Set 1 | tommot
# Processing Record 121 of Set 1 | lebu
# Processing Record 122 of Set 1 | jaguarari
# Processing Record 123 of Set 1 | port lincoln
# Processing Record 124 of Set 1 | saldanha
# Processing Record 125 of Set 1 | bathsheba
# Processing Record 126 of Set 1 | puerto ayora
# Processing Record 127 of Set 1 | pevek
# Processing Record 128 of Set 1 | chokurdakh
# Processing Record 129 of Set 1 | dingle
# Processing Record 130 of Set 1 | nanortalik
# Processing Record 131 of Set 1 | jamestown
# Processing Record 132 of Set 1 | tasbuget
# City not found. Skipping...
# Processing Record 133 of Set 1 | sorong
# Processing Record 134 of Set 1 | goundam
# Processing Record 135 of Set 1 | linqiong
# Processing Record 136 of Set 1 | hay river
# Processing Record 137 of Set 1 | paoua
# Processing Record 138 of Set 1 | taunggyi
# Processing Record 139 of Set 1 | port hardy
# Processing Record 140 of Set 1 | petropavlovskoye
# Processing Record 141 of Set 1 | evensk
# Processing Record 142 of Set 1 | kachug
# Processing Record 143 of Set 1 | hambantota
# Processing Record 144 of Set 1 | broome
# Processing Record 145 of Set 1 | vila
# Processing Record 146 of Set 1 | ahumada
# City not found. Skipping...
# Processing Record 147 of Set 1 | batagay
# Processing Record 148 of Set 1 | singaparna
# Processing Record 149 of Set 1 | vila franca do campo
# Processing Record 150 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 151 of Set 1 | marrakesh
# Processing Record 152 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 153 of Set 1 | avarua
# Processing Record 154 of Set 1 | umm lajj
# Processing Record 155 of Set 1 | souillac
# Processing Record 156 of Set 1 | port elizabeth
# Processing Record 157 of Set 1 | tautira
# Processing Record 158 of Set 1 | les cayes
# Processing Record 159 of Set 1 | yertsevo
# Processing Record 160 of Set 1 | moree
# Processing Record 161 of Set 1 | kahului
# Processing Record 162 of Set 1 | caravelas
# Processing Record 163 of Set 1 | jizan
# Processing Record 164 of Set 1 | fallon
# Processing Record 165 of Set 1 | pacific grove
# Processing Record 166 of Set 1 | victoria
# Processing Record 167 of Set 1 | khonsa
# Processing Record 168 of Set 1 | castro
# Processing Record 169 of Set 1 | sabha
# Processing Record 170 of Set 1 | hasaki
# Processing Record 171 of Set 1 | saint-pierre
# Processing Record 172 of Set 1 | marienburg
# Processing Record 173 of Set 1 | nome
# Processing Record 174 of Set 1 | polis
# Processing Record 175 of Set 1 | douglas
# Processing Record 176 of Set 1 | araouane
# Processing Record 177 of Set 1 | touros
# Processing Record 178 of Set 1 | emba
# Processing Record 179 of Set 1 | ribas do rio pardo
# Processing Record 180 of Set 1 | raduzhnyy
# Processing Record 181 of Set 1 | yellowknife
# Processing Record 182 of Set 1 | okhotsk
# Processing Record 183 of Set 1 | keti bandar
# Processing Record 184 of Set 1 | ketchikan
# Processing Record 185 of Set 1 | tasiilaq
# Processing Record 186 of Set 1 | dalbandin
# Processing Record 187 of Set 1 | barrow
# Processing Record 188 of Set 1 | bubaque
# Processing Record 189 of Set 1 | serik
# Processing Record 190 of Set 1 | haifa
# Processing Record 191 of Set 1 | cabra
# Processing Record 192 of Set 1 | cururupu
# Processing Record 193 of Set 1 | roma
# Processing Record 194 of Set 1 | constitucion
# Processing Record 195 of Set 1 | methoni
# Processing Record 196 of Set 1 | saquena
# Processing Record 197 of Set 1 | yuncheng
# Processing Record 198 of Set 1 | deputatskiy
# Processing Record 199 of Set 1 | te anau
# Processing Record 200 of Set 1 | lecce
# Processing Record 201 of Set 1 | hofn
# Processing Record 202 of Set 1 | leningradskiy
# Processing Record 203 of Set 1 | nioaque
# Processing Record 204 of Set 1 | east london
# Processing Record 205 of Set 1 | shamli
# Processing Record 206 of Set 1 | biak
# Processing Record 207 of Set 1 | colomi
# Processing Record 208 of Set 1 | strand
# Processing Record 209 of Set 1 | sitka
# Processing Record 210 of Set 1 | shingu
# Processing Record 211 of Set 1 | henties bay
# Processing Record 212 of Set 1 | corinto
# Processing Record 213 of Set 1 | cabo san lucas
# Processing Record 214 of Set 1 | warrington
# Processing Record 215 of Set 1 | coquimbo
# Processing Record 216 of Set 1 | kamaishi
# Processing Record 217 of Set 1 | japura
# Processing Record 218 of Set 1 | meadow lake
# Processing Record 219 of Set 1 | jiangyou
# Processing Record 220 of Set 1 | lichuan
# Processing Record 221 of Set 1 | hithadhoo
# Processing Record 222 of Set 1 | maloy
# Processing Record 223 of Set 1 | buraydah
# Processing Record 224 of Set 1 | ilulissat
# Processing Record 225 of Set 1 | sabya
# Processing Record 226 of Set 1 | caluquembe
# Processing Record 227 of Set 1 | clyde river
# Processing Record 228 of Set 1 | orangeburg
# Processing Record 229 of Set 1 | samarai
# Processing Record 230 of Set 1 | longyearbyen
# Processing Record 231 of Set 1 | saltpond
# Processing Record 232 of Set 1 | cortes
# Processing Record 233 of Set 1 | satitoa
# City not found. Skipping...
# Processing Record 234 of Set 1 | isilkul
# Processing Record 235 of Set 1 | gondar
# Processing Record 236 of Set 1 | sivaki
# Processing Record 237 of Set 1 | burnie
# Processing Record 238 of Set 1 | acapulco
# Processing Record 239 of Set 1 | lewistown
# Processing Record 240 of Set 1 | jiayuguan
# Processing Record 241 of Set 1 | chuy
# Processing Record 242 of Set 1 | longlac
# City not found. Skipping...
# Processing Record 243 of Set 1 | nisia floresta
# Processing Record 244 of Set 1 | qasigiannguit
# Processing Record 245 of Set 1 | sakakah
# City not found. Skipping...
# Processing Record 246 of Set 1 | safranbolu
# Processing Record 247 of Set 1 | dongsheng
# Processing Record 248 of Set 1 | urubicha
# Processing Record 249 of Set 1 | poum
# Processing Record 250 of Set 1 | celestun
# Processing Record 251 of Set 1 | abnub
# Processing Record 252 of Set 1 | sobolevo
# Processing Record 253 of Set 1 | tiarei
# Processing Record 254 of Set 1 | kawana waters
# City not found. Skipping...
# Processing Record 255 of Set 1 | kropotkin
# Processing Record 256 of Set 1 | det udom
# Processing Record 257 of Set 1 | goderich
# Processing Record 258 of Set 1 | guajara-mirim
# City not found. Skipping...
# Processing Record 259 of Set 1 | bograd
# Processing Record 260 of Set 1 | port hedland
# Processing Record 261 of Set 1 | portneuf
# Processing Record 262 of Set 1 | havoysund
# Processing Record 263 of Set 1 | paamiut
# Processing Record 264 of Set 1 | faanui
# Processing Record 265 of Set 1 | svetlogorsk
# Processing Record 266 of Set 1 | piacabucu
# Processing Record 267 of Set 1 | kirakira
# Processing Record 268 of Set 1 | walvis bay
# Processing Record 269 of Set 1 | nador
# Processing Record 270 of Set 1 | ojinaga
# Processing Record 271 of Set 1 | adrar
# Processing Record 272 of Set 1 | guerrero negro
# Processing Record 273 of Set 1 | brookings
# Processing Record 274 of Set 1 | porto santo
# City not found. Skipping...
# Processing Record 275 of Set 1 | bosaso
# Processing Record 276 of Set 1 | coruripe
# Processing Record 277 of Set 1 | port blair
# Processing Record 278 of Set 1 | saint george
# Processing Record 279 of Set 1 | tomari
# Processing Record 280 of Set 1 | bulgan
# Processing Record 281 of Set 1 | chagda
# City not found. Skipping...
# Processing Record 282 of Set 1 | shumskiy
# Processing Record 283 of Set 1 | kurumkan
# Processing Record 284 of Set 1 | belawan
# Processing Record 285 of Set 1 | nelson bay
# Processing Record 286 of Set 1 | guanica
# Processing Record 287 of Set 1 | oneonta
# Processing Record 288 of Set 1 | kunjah
# Processing Record 289 of Set 1 | abreus
# Processing Record 290 of Set 1 | boke
# Processing Record 291 of Set 1 | carutapera
# Processing Record 292 of Set 1 | yuzhno-kurilsk
# Processing Record 293 of Set 1 | buala
# Processing Record 294 of Set 1 | pangnirtung
# Processing Record 295 of Set 1 | cayenne
# Processing Record 296 of Set 1 | pacifica
# Processing Record 297 of Set 1 | provideniya
# Processing Record 298 of Set 1 | huaiyin
# Processing Record 299 of Set 1 | balykshi
# City not found. Skipping...
# Processing Record 300 of Set 1 | hervey bay
# Processing Record 301 of Set 1 | marabba
# Processing Record 302 of Set 1 | moctezuma
# Processing Record 303 of Set 1 | makinsk
# Processing Record 304 of Set 1 | hatillo
# Processing Record 305 of Set 1 | tlahualilo
# City not found. Skipping...
# Processing Record 306 of Set 1 | high level
# Processing Record 307 of Set 1 | indianola
# Processing Record 308 of Set 1 | corn island
# Processing Record 309 of Set 1 | nhulunbuy
# Processing Record 310 of Set 1 | tura
# Processing Record 311 of Set 1 | khromtau
# Processing Record 312 of Set 1 | olovyannaya
# Processing Record 313 of Set 1 | sovetskiy
# Processing Record 314 of Set 1 | mbulu
# Processing Record 315 of Set 1 | ryazhsk
# Processing Record 316 of Set 1 | hualmay
# Processing Record 317 of Set 1 | nokaneng
# Processing Record 318 of Set 1 | hurghada
# City not found. Skipping...
# Processing Record 319 of Set 1 | flinders
# Processing Record 320 of Set 1 | puerto madero
# Processing Record 321 of Set 1 | jalingo
# Processing Record 322 of Set 1 | tarabuco
# Processing Record 323 of Set 1 | corrales
# Processing Record 324 of Set 1 | santander
# Processing Record 325 of Set 1 | hirara
# Processing Record 326 of Set 1 | veraval
# Processing Record 327 of Set 1 | amapa
# Processing Record 328 of Set 1 | borodino
# Processing Record 329 of Set 1 | bairiki
# City not found. Skipping...
# Processing Record 330 of Set 1 | macara
# City not found. Skipping...
# Processing Record 331 of Set 1 | egvekinot
# Processing Record 332 of Set 1 | mogadishu
# Processing Record 333 of Set 1 | banda aceh
# Processing Record 334 of Set 1 | shimoda
# Processing Record 335 of Set 1 | sayyan
# Processing Record 336 of Set 1 | lavrentiya
# Processing Record 337 of Set 1 | kavieng
# Processing Record 338 of Set 1 | halalo
# City not found. Skipping...
# Processing Record 339 of Set 1 | taltal
# Processing Record 340 of Set 1 | udaipura
# Processing Record 341 of Set 1 | jertih
# Processing Record 342 of Set 1 | tsihombe
# City not found. Skipping...
# Processing Record 343 of Set 1 | iskilip
# Processing Record 344 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 345 of Set 1 | westport
# Processing Record 346 of Set 1 | iqaluit
# Processing Record 347 of Set 1 | pascagoula
# Processing Record 348 of Set 1 | pundaguitan
# Processing Record 349 of Set 1 | kuryk
# Processing Record 350 of Set 1 | midland
# Processing Record 351 of Set 1 | fairbanks
# Processing Record 352 of Set 1 | townsville
# Processing Record 353 of Set 1 | lolua
# City not found. Skipping...
# Processing Record 354 of Set 1 | canico
# Processing Record 355 of Set 1 | cernilov
# Processing Record 356 of Set 1 | kuusamo
# Processing Record 357 of Set 1 | greymouth
# Processing Record 358 of Set 1 | vao
# Processing Record 359 of Set 1 | cozumel
# City not found. Skipping...
# Processing Record 360 of Set 1 | dori
# Processing Record 361 of Set 1 | jacareacanga
# Processing Record 362 of Set 1 | aras
# Processing Record 363 of Set 1 | lagoa
# Processing Record 364 of Set 1 | kungurtug
# Processing Record 365 of Set 1 | alpena
# Processing Record 366 of Set 1 | san patricio
# Processing Record 367 of Set 1 | safwah
# City not found. Skipping...
# Processing Record 368 of Set 1 | escondido
# Processing Record 369 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 370 of Set 1 | poya
# Processing Record 371 of Set 1 | ballina
# Processing Record 372 of Set 1 | cidreira
# Processing Record 373 of Set 1 | atar
# Processing Record 374 of Set 1 | san matias
# Processing Record 375 of Set 1 | waipawa
# Processing Record 376 of Set 1 | kavaratti
# Processing Record 377 of Set 1 | aklavik
# Processing Record 378 of Set 1 | kurilsk
# Processing Record 379 of Set 1 | matagami
# Processing Record 380 of Set 1 | cortez
# Processing Record 381 of Set 1 | fuzhou
# Processing Record 382 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 383 of Set 1 | beaupre
# Processing Record 384 of Set 1 | jalu
# Processing Record 385 of Set 1 | alice springs
# Processing Record 386 of Set 1 | kuchaman
# Processing Record 387 of Set 1 | wahiawa
# Processing Record 388 of Set 1 | ambon
# Processing Record 389 of Set 1 | chishtian mandi
# Processing Record 390 of Set 1 | tshela
# Processing Record 391 of Set 1 | sambava
# Processing Record 392 of Set 1 | barkhan
# Processing Record 393 of Set 1 | komsomolskiy
# Processing Record 394 of Set 1 | arteaga
# Processing Record 395 of Set 1 | lalomanu
# City not found. Skipping...
# Processing Record 396 of Set 1 | traralgon
# Processing Record 397 of Set 1 | mocambique
# City not found. Skipping...
# Processing Record 398 of Set 1 | buzmeyin
# Processing Record 399 of Set 1 | biarritz
# Processing Record 400 of Set 1 | mentok
# City not found. Skipping...
# Processing Record 401 of Set 1 | asarganj
# Processing Record 402 of Set 1 | polyarnyy
# Processing Record 403 of Set 1 | belen
# Processing Record 404 of Set 1 | marinette
# Processing Record 405 of Set 1 | kudahuvadhoo
# Processing Record 406 of Set 1 | svetlaya
# Processing Record 407 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 408 of Set 1 | nouadhibou
# Processing Record 409 of Set 1 | lumeje
# Processing Record 410 of Set 1 | mar del plata
# Processing Record 411 of Set 1 | bethel
# Processing Record 412 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 413 of Set 1 | namatanai
# Processing Record 414 of Set 1 | surgut
# Processing Record 415 of Set 1 | soyo
# Processing Record 416 of Set 1 | montepuez
# Processing Record 417 of Set 1 | coahuayana
# Processing Record 418 of Set 1 | northampton
# Processing Record 419 of Set 1 | kyrylivka
# Processing Record 420 of Set 1 | sola
# Processing Record 421 of Set 1 | thap than
# Processing Record 422 of Set 1 | nizhniy kuranakh
# Processing Record 423 of Set 1 | smirnykh
# Processing Record 424 of Set 1 | fort nelson
# Processing Record 425 of Set 1 | haines junction
# Processing Record 426 of Set 1 | iisalmi
# Processing Record 427 of Set 1 | xiongzhou
# Processing Record 428 of Set 1 | venado tuerto
# Processing Record 429 of Set 1 | porbandar
# Processing Record 430 of Set 1 | kenitra
# Processing Record 431 of Set 1 | dali
# Processing Record 432 of Set 1 | kamenskoye
# City not found. Skipping...
# Processing Record 433 of Set 1 | abraveses
# Processing Record 434 of Set 1 | portland
# Processing Record 435 of Set 1 | puerto narino
# Processing Record 436 of Set 1 | harper
# Processing Record 437 of Set 1 | axim
# Processing Record 438 of Set 1 | beloha
# Processing Record 439 of Set 1 | manokwari
# Processing Record 440 of Set 1 | banjar
# Processing Record 441 of Set 1 | homer
# Processing Record 442 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 443 of Set 1 | gizo
# Processing Record 444 of Set 1 | ornskoldsvik
# Processing Record 445 of Set 1 | cockburn town
# Processing Record 446 of Set 1 | qui nhon
# City not found. Skipping...
# Processing Record 447 of Set 1 | vestmannaeyjar
# Processing Record 448 of Set 1 | andenes
# City not found. Skipping...
# Processing Record 449 of Set 1 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 450 of Set 1 | teguise
# Processing Record 451 of Set 1 | pingdingshan
# Processing Record 452 of Set 1 | xining
# Processing Record 453 of Set 1 | correia pinto
# Processing Record 454 of Set 1 | ixtapa
# Processing Record 455 of Set 1 | macheng
# Processing Record 456 of Set 1 | fukue
# Processing Record 457 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 458 of Set 1 | nishihara
# Processing Record 459 of Set 1 | santa rosa de lima
# Processing Record 460 of Set 1 | meulaboh
# Processing Record 461 of Set 1 | norrtalje
# Processing Record 462 of Set 1 | campbell river
# Processing Record 463 of Set 1 | gilgil
# City not found. Skipping...
# Processing Record 464 of Set 1 | grand gaube
# Processing Record 465 of Set 1 | margate
# Processing Record 466 of Set 1 | kununurra
# Processing Record 467 of Set 1 | flin flon
# Processing Record 468 of Set 1 | maniitsoq
# Processing Record 469 of Set 1 | mangrol
# Processing Record 470 of Set 1 | port moresby
# Processing Record 471 of Set 1 | kieta
# Processing Record 472 of Set 1 | hibbing
# Processing Record 473 of Set 1 | altamira
# Processing Record 474 of Set 1 | oum hadjer
# Processing Record 475 of Set 1 | aflu
# City not found. Skipping...
# Processing Record 476 of Set 1 | kingman
# Processing Record 477 of Set 1 | floro
# Processing Record 478 of Set 1 | torbay
# Processing Record 479 of Set 1 | kazalinsk
# City not found. Skipping...
# Processing Record 480 of Set 1 | kolpashevo
# Processing Record 481 of Set 1 | paraiso
# Processing Record 482 of Set 1 | bardiyah
# City not found. Skipping...
# Processing Record 483 of Set 1 | viedma
# Processing Record 484 of Set 1 | san vicente
# Processing Record 485 of Set 1 | fukuma
# Processing Record 486 of Set 1 | omboue
# Processing Record 487 of Set 1 | yershichi
# Processing Record 488 of Set 1 | katsuura
# Processing Record 489 of Set 1 | locri
# Processing Record 490 of Set 1 | zatoka
# Processing Record 491 of Set 1 | tessalit
# Processing Record 492 of Set 1 | san pedro
# Processing Record 493 of Set 1 | jaipur hat
# City not found. Skipping...
# Processing Record 494 of Set 1 | lahaina
# Processing Record 495 of Set 1 | nenjiang
# Processing Record 496 of Set 1 | ban nahin
# Processing Record 497 of Set 1 | islamkot
# Processing Record 498 of Set 1 | jiaonan
# Processing Record 499 of Set 1 | alofi
# Processing Record 500 of Set 1 | bilma
# Processing Record 501 of Set 1 | howard springs
# Processing Record 502 of Set 1 | mezen
# Processing Record 503 of Set 1 | dharmapuri
# Processing Record 504 of Set 1 | hearst
# Processing Record 505 of Set 1 | moron
# Processing Record 506 of Set 1 | richards bay
# Processing Record 507 of Set 1 | muros
# Processing Record 508 of Set 1 | kikwit
# Processing Record 509 of Set 1 | tiksi
# Processing Record 510 of Set 1 | ialibu
# Processing Record 511 of Set 1 | yining
# Processing Record 512 of Set 1 | awbari
# Processing Record 513 of Set 1 | urdzhar
# City not found. Skipping...
# Processing Record 514 of Set 1 | teknaf
# Processing Record 515 of Set 1 | odienne
# Processing Record 516 of Set 1 | los llanos de aridane
# Processing Record 517 of Set 1 | sierra vista
# Processing Record 518 of Set 1 | aswan
# Processing Record 519 of Set 1 | trelew
# Processing Record 520 of Set 1 | eyl
# Processing Record 521 of Set 1 | severo-yeniseyskiy
# Processing Record 522 of Set 1 | amazar
# Processing Record 523 of Set 1 | ginir
# Processing Record 524 of Set 1 | dabat
# Processing Record 525 of Set 1 | summerville
# Processing Record 526 of Set 1 | jinchang
# Processing Record 527 of Set 1 | brae
# Processing Record 528 of Set 1 | nara
# Processing Record 529 of Set 1 | ribeira grande
# Processing Record 530 of Set 1 | baruun-urt
# Processing Record 531 of Set 1 | illela
# Processing Record 532 of Set 1 | ust-kachka
# Processing Record 533 of Set 1 | rocha
# Processing Record 534 of Set 1 | luderitz
# Processing Record 535 of Set 1 | maroantsetra
# Processing Record 536 of Set 1 | konstancin-jeziorna
# Processing Record 537 of Set 1 | riyadh
# Processing Record 538 of Set 1 | hamilton
# Processing Record 539 of Set 1 | conceicao do mato dentro
# Processing Record 540 of Set 1 | lethem
# Processing Record 541 of Set 1 | grindavik
# Processing Record 542 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 543 of Set 1 | taonan
# Processing Record 544 of Set 1 | shushtar
# Processing Record 545 of Set 1 | omsukchan
# Processing Record 546 of Set 1 | loa janan
# Processing Record 547 of Set 1 | karpathos
# Processing Record 548 of Set 1 | turayf
# Processing Record 549 of Set 1 | kimbe
# Processing Record 550 of Set 1 | petropavlovsk-kamchatskiy
# Processing Record 551 of Set 1 | nipawin
# Processing Record 552 of Set 1 | birao
# Processing Record 553 of Set 1 | dutlwe
# Processing Record 554 of Set 1 | san andres
# Processing Record 555 of Set 1 | honiara
# Processing Record 556 of Set 1 | naze
# Processing Record 557 of Set 1 | samalaeulu
# City not found. Skipping...
# Processing Record 558 of Set 1 | vestmanna
# Processing Record 559 of Set 1 | urdoma
# Processing Record 560 of Set 1 | padang
# Processing Record 561 of Set 1 | valverde del camino
# Processing Record 562 of Set 1 | mayumba
# Processing Record 563 of Set 1 | papara
# Processing Record 564 of Set 1 | buariki
# City not found. Skipping...
# Processing Record 565 of Set 1 | warqla
# City not found. Skipping...
# Processing Record 566 of Set 1 | vila velha
# Processing Record 567 of Set 1 | llanes
# Processing Record 568 of Set 1 | kraslava
# Processing Record 569 of Set 1 | skjold
# Processing Record 570 of Set 1 | lata
# Processing Record 571 of Set 1 | comodoro rivadavia
# Processing Record 572 of Set 1 | palmer
# Processing Record 573 of Set 1 | passagem franca
# Processing Record 574 of Set 1 | porto de moz
# Processing Record 575 of Set 1 | grootfontein
# Processing Record 576 of Set 1 | marystown
# Processing Record 577 of Set 1 | ust-maya
# Processing Record 578 of Set 1 | kilindoni
# Processing Record 579 of Set 1 | skibotn
# Processing Record 580 of Set 1 | richard toll
# City not found. Skipping...
# Processing Record 581 of Set 1 | sebinkarahisar
# Processing Record 582 of Set 1 | kibala
# Processing Record 583 of Set 1 | sistranda
# Processing Record 584 of Set 1 | dunedin
# Processing Record 585 of Set 1 | urumqi
# City not found. Skipping...
# Processing Record 586 of Set 1 | doha
# Processing Record 587 of Set 1 | lubumbashi
# Processing Record 588 of Set 1 | troitskoye
# Processing Record 589 of Set 1 | wilmington
# Processing Record 590 of Set 1 | kasongo-lunda
# Processing Record 591 of Set 1 | bambanglipuro
# Processing Record 592 of Set 1 | nykoping
# Processing Record 593 of Set 1 | invermere
# Processing Record 594 of Set 1 | anadyr
# Processing Record 595 of Set 1 | kembe
# City not found. Skipping...
# Processing Record 596 of Set 1 | simpang
# Processing Record 597 of Set 1 | yerbabuena
# Processing Record 598 of Set 1 | coulihaut
# City not found. Skipping...
# Processing Record 599 of Set 1 | outjo
# Processing Record 600 of Set 1 | devarkonda
# Processing Record 601 of Set 1 | ayan
# Processing Record 602 of Set 1 | cooma
# Processing Record 603 of Set 1 | manuk mangkaw
# Processing Record 604 of Set 1 | aksarka
# Processing Record 605 of Set 1 | kotar
# Processing Record 606 of Set 1 | kamenka
# Processing Record 607 of Set 1 | pisco
# Processing Record 608 of Set 1 | upata
# Processing Record 609 of Set 1 | ancud
# Processing Record 610 of Set 1 | maceio
# Processing Record 611 of Set 1 | wasilla
# Processing Record 612 of Set 1 | surin
# Processing Record 613 of Set 1 | arlit
# Processing Record 614 of Set 1 | pemba
# Processing Record 615 of Set 1 | kindu
# Processing Record 616 of Set 1 | louisbourg
# City not found. Skipping...
# Processing Record 617 of Set 1 | teya
# Processing Record 618 of Set 1 | haibowan
# City not found. Skipping...
# Processing Record 619 of Set 1 | yebaishou
# Processing Record 620 of Set 1 | grand island
# Processing Record 621 of Set 1 | mabaruma
# Processing Record 622 of Set 1 | kalianget
# Processing Record 623 of Set 1 | geraldton
# Processing Record 624 of Set 1 | cairns
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#f = csv.writer(open("city_data.csv", "w"))

#f.writerow(["City", "Cloudiness", "Country", "Date", "Humidity", "Lat", "Lng", "Max Temp", "Wind Speed"])

#for cities in cities_json:
   # f.writerow([cities_json["city"]
 #               cities_json["clouds"]["all"]
 #               cities_json["sys"]["country"]
  #              cities_json["dt"]
  #              cities_json["main"]["humidity"]
   #             cities_json["coord"]["lat"]
  #              cities_json["coord"]["lon"]
  #              cities_json["main"]["temp_max"]
   #             cities_json["wind"]["speed"]
  #              ])

# %%
df_cities = pd.DataFrame(cities_json)

# %%
df_cities.count()
# Out:
# City          561
# Cloudiness    561
# Country       561
# Date          561
# Humidity      561
# Lat           561
# Lng           561
# Max Temp      561
# Wind Speed    561
# dtype: int64

# %%
df_cities.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat     Lng  \
# 0        Vitim           0      RU  1537752966        67  59.44  112.57
# 1        Bluff           0      AU  1537752966        33 -23.58  149.07
# 2    Springbok          36      ZA  1537752966        37 -29.67   17.88
# 3  Broken Hill           0      AU  1537752966        48 -31.97  141.45
# 4      Lazarev          48      RU  1537752967        88  52.23  141.51
#
#    Max Temp  Wind Speed
# 0     51.50        3.18
# 1     82.46        5.19
# 2     50.24        4.52
# 3     63.74       11.79
# 4     56.45        2.28

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(df_cities["Lat"],df_cities["Max Temp"], marker="o", facecolors="#2474AC", edgecolors="black")
plt.title("City Latitude vs. Temperature")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (F)")

plt.xlim(-70,85)
plt.ylim(0,120)
plt.grid()

plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(df_cities["Lat"],df_cities["Humidity"], marker="o", facecolors="#2474AC", edgecolors="black")
plt.title("City Latitude vs. Humidity")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")

plt.xlim(-65,85)
plt.ylim(0,110)

plt.grid()

plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(df_cities["Lat"],df_cities["Cloudiness"], marker="o", facecolors="#2474AC", edgecolors="black")
plt.title("City Latitude vs. Cloudiness")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")

plt.xlim(-65,85)
plt.ylim(-10,105)

plt.grid()

plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(df_cities["Lat"],df_cities["Wind Speed"], marker="o", facecolors="#2474AC", edgecolors="black")
plt.title("City Latitude vs. Wind Speed")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (mph)")

plt.xlim(-65,85)
plt.ylim(-2,40)
plt.grid()

plt.show()
